# %%
import pandas as pd # import and manage datasets
import numpy as np # mathematic library

# %%
df_personnel = pd.read_excel('PersonnelOnShift.xlsx')

# %%
df_personnel.head()
# Out:
#    report_week hospital_code  er_staff_residents_and_rural_day_on_call  \
# 0  30 del 2019        AMA000                                         0
# 1  29 del 2019        AMA000                                         1
# 2  35 del 2019        AMA000                                         1
# 3  28 del 2019        AMA000                                         1
# 4  45 del 2019        AMA000                                         2
#
#    er_staff_specialist_day_on_call  er_staff_mic_day_on_call  \
# 0                                2                         2
# 1                                2                         2
# 2                                4                         2
# 3                                3                         2
# 4                                2                         2
#
#    er_staff_nurse_day_on_call  er_staff_non_professional_nurse_day_on_call  \
# 0                           2                                            2
# ...

# %%
df910 = pd.read_excel('data4pg910.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04f687de28b9> in <module>
# ----> 1 df910 = df.read_excel('data4pg910.xlsx')
#
# NameError: name 'df' is not defined

# %%
df910.head()
# Out:
#    report_week hospital_code strike_medical_staff_affected  \
# 0  30 del 2019        AMA000                           NaN
# 1  29 del 2019        AMA000                           NaN
# 2  35 del 2019        AMA000                           NaN
# 3  28 del 2019        AMA000                           NaN
# 4  45 del 2019        AMA000                           NaN
#
#   strike_nurses_affected strike_other_staff_affected strike_patients_affected  \
# 0                    NaN                         NaN                      NaN
# 1                    NaN                         NaN                      NaN
# 2                    NaN                         NaN                      NaN
# 3                    NaN                         NaN                      NaN
# 4                    NaN                         NaN                      NaN
#
#   strike_other_affected                    staff_violence_affected_reasons  \
# ...
